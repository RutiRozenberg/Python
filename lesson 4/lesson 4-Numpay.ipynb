# %%
pip install numpy
# Out:
# ...
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/61.0 kB ? eta -:--:--
#      ------------------- ------------------ 30.7/61.0 kB 435.7 kB/s eta 0:00:01
#      -------------------------------------- 61.0/61.0 kB 540.4 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    ---------------------------------------- 0.1/15.8 MB 1.3 MB/s eta 0:00:12
#    ---------------------------------------- 0.2/15.8 MB 1.2 MB/s eta 0:00:13
#     --------------------------------------- 0.2/15.8 MB 1.3 MB/s eta 0:00:13
#     --------------------------------------- 0.3/15.8 MB 1.4 MB/s eta 0:00:11
#     --------------------------------------- 0.3/15.8 MB 1.4 MB/s eta 0:00:11
# ...

# %%
import numpy as np

# %%
array = np.random.randint(1,50,size=(10))
np.mean(array)
# Out:
# 35.2

# %%
a=np.array([[1,2,3],[1,2,2]])
b=np.array([[5,4,7],[4,5,8]])
np.mean(a+b)
# Out:
# 7.333333333333333

# %%
array = np.random.randint(1,100,size=(20))
filtered_arr = array[array >50]
filtered_arr
# Out:
# array([82, 75, 52, 82, 94, 56, 55, 97])

# %%
array = np.random.randint(1,10,size=(20))
np.random.shuffle(array)
filter=array[array>np.random.randint(1,10)]
filter
# Out:
# array([9, 6, 7, 6, 9, 6, 9])
